# %%
import requests
base_url = "https://08ccd6218a99.ngrok-free.app"

# %%
# base_url = "http://localhost:8000"


# Get cells in Kigali province
import requests
endpoint = "cells"
response = requests.get(f"{base_url}/cells", params={"province": "Kigali"})
response = requests.get(full_url)
data = response.json()
print(f"Found {data['count']} cells in Kigali")

# Get population data
response = requests.get(f"{base_url}/population", params={"limit": 5})
population_data = response.json()
for cell in population_data['data']:
    print(f"{cell['cell_name']}: {cell['general_pop']} people")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       1 # base_url = "http://localhost:8000"
#       2
#       3
#       4 # Get cells in Kigali province
#       5 #response = requests.get(f"{base_url}/cells", params={"province": "Kigali"})
# ----> 6 response = requests.get(full_url)
#       7 data = response.json()
#       8 print(f"Found {data['count']} cells in Kigali")
#
# NameError: name 'full_url' is not defined

# %%
import requests  # correct spelling of the library

endpoint = "cells"
# full_url = f"{base_url}/{endpoint}"   # use / instead of , 
full_url = f" {base_url}/{endpoint}"
response = requests.get(full_url)     # correct spelling
data = response.json()                # fixed variable name

print(f"Found {data['count']} cells in Kigali")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/anaconda3/lib/python3.13/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/anaconda3/lib/python3.13/site-packages/urllib3/connection.py:741, in HTTPSConnection.connect(self)
#     739 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...
